# %% [markdown]
# # Air tem_LAO

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Air tem_LAO.csv')
data
# Out:
#    Province Name(1)   Province Name(2)  2019  2020  2021
# 0   Northern Region          Phongsaly  21.6  20.8  20.2
# 1   Northern Region        Luangnamtha  25.3  25.0  24.4
# 2   Northern Region           Oudomxay  24.9  24.6  24.2
# 3   Northern Region              Bokeo  27.5  27.3  26.6
# 4   Northern Region       Luangprabang  26.4  26.4  26.2
# 5   Northern Region           Huaphanh  22.4  21.9  21.6
# 6   Northern Region          Xayaboury  25.8  25.9  25.3
# 7    Central Region  Vientiane Capital  22.7  27.6  21.9
# 8    Central Region        Xiengkhuang  27.9  22.3  27.3
# 9    Central Region          Vientiane  28.3  27.9  27.6
# 10   Central Region        Borikhamxay  28.3  27.6  27.6
# 11   Central Region          Khammuane  28.8  28.4  27.9
# 12   Central Region        Savannakhet  27.6  27.1  26.6
# 13   Central Region         Xaysomboon  22.6  22.7  22.0
# 14  Southern Region            Saravan  27.2  27.2  26.6
# ...

# %% [markdown]
# ## Change columns name

# %%
data = data.rename(columns={"Province Name(1)":"Region", "Province Name(2)":"Province"})
data
# Out:
#              Region           Province  2019  2020  2021
# 0   Northern Region          Phongsaly  21.6  20.8  20.2
# 1   Northern Region        Luangnamtha  25.3  25.0  24.4
# 2   Northern Region           Oudomxay  24.9  24.6  24.2
# 3   Northern Region              Bokeo  27.5  27.3  26.6
# 4   Northern Region       Luangprabang  26.4  26.4  26.2
# 5   Northern Region           Huaphanh  22.4  21.9  21.6
# 6   Northern Region          Xayaboury  25.8  25.9  25.3
# 7    Central Region  Vientiane Capital  22.7  27.6  21.9
# 8    Central Region        Xiengkhuang  27.9  22.3  27.3
# 9    Central Region          Vientiane  28.3  27.9  27.6
# 10   Central Region        Borikhamxay  28.3  27.6  27.6
# 11   Central Region          Khammuane  28.8  28.4  27.9
# 12   Central Region        Savannakhet  27.6  27.1  26.6
# 13   Central Region         Xaysomboon  22.6  22.7  22.0
# 14  Southern Region            Saravan  27.2  27.2  26.6
# ...

# %% [markdown]
# ## Define X_axis and Y_data

# %%
x=data['Province', size=15]
y1=data['2019', size=15]
y2=data['2020', ]
y3=data['2021']

# %%
y1
# Out:
# 0     21.6
# 1     25.3
# 2     24.9
# 3     27.5
# 4     26.4
# 5     22.4
# 6     25.8
# 7     22.7
# 8     27.9
# 9     28.3
# 10    28.3
# 11    28.8
# 12    27.6
# 13    22.6
# 14    27.2
# 15    26.9
# 16    28.3
# 17    29.7
# Name: 2019, dtype: float64

# %%
plt.figure(figsize=(20,5))
plt.bar(x,y1)
# Out:
# <BarContainer object of 18 artists>

# %% [markdown]
# ## Change axis

# %%
plt.figure(figsize=(20,10))
plt.barh(x,y1)
plt.xlabel('Temperature', size=15)
plt.title('Atmospheric Temperature of Laos', size=15)
# Out:
# Text(0.5, 1.0, 'Atmospheric Temperature of Laos')

# %% [markdown]
# ## Another

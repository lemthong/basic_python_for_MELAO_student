# %% [markdown]
# # My python plot

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import plotly as pl
import floweaver as flv

# %%
data = pd.read_csv('Sugarcane production_LAO.csv')
data
# Out:
#     Name of  Province(1)  Name of  Province(2)                 2010  \
# 0   Name of  Province(1)  Name of  Province(2)  Harvested Area (ha)
# 1                  Total           Sub Summary                15355
# 2        Northern Region           Sub Summary                 4400
# 3        Northern Region             Phongsaly                 1445
# 4        Northern Region           Luangnamtha                 2075
# 5        Northern Region              Oudomxay                  565
# 6        Northern Region                 Bokeo                  ...
# 7        Northern Region          Luangprabang                   60
# 8        Northern Region              Huaphanh                  140
# 9        Northern Region             Xayaboury                  115
# 10        Central Region           Sub Summary                10410
# 11        Central Region     Vientiane Capital                  120
# 12        Central Region           Xiengkhuang                   70
# ...
